# %% [markdown]
# # Solving a Rubik's cube with RL

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Playground

# %%
from rubik import *

# %%
cube = RubiksCube(shuffle = False)
# Out:
# Initialized RubiksCube

# %%
cube.render()

# %%
cube.get_face("RIGHT")
# Out:
# array([[2, 2, 2],
#        [2, 2, 2],
#        [2, 2, 2]])

# %%
cube.data[0] = 3

# %%
cube.render()

# %%
cube.get_face("LEFT")
# Out:
# array([[3, 0, 0],
#        [0, 0, 0],
#        [0, 0, 0]])

# %%
x = cube.get_face("LEFT")

# %%
RubiksFace(x).render()

# %%
RubiksFace(np.rot90(x,k=-1)).render()
